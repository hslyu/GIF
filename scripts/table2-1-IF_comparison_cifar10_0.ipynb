# %%
# %env CUDA_VISIBLE_DEVICES=0
# Out:
# env: CUDA_VISIBLE_DEVICES=0

# %%
#! /usr/bin/env python3
# -*- coding: utf-8 -*-
import os
import gc

import numpy as np
import torch
import torch.backends.cudnn as cudnn
from torch import nn

from dataloader import cifar10
from models import VGG11
from src import freeze_influence, hessians, selection, second_influence

device = "cuda" if torch.cuda.is_available() else "cpu"
target_removal_label = 0

# %%
def load_net(net, path):
    assert os.path.isfile(path), "Error: no checkpoint file found!"
    checkpoint = torch.load(path)
    net.load_state_dict(checkpoint["net"])
    return net


def save_net(net, path):
    dir, filename = os.path.split(path)
    if not os.path.isdir(dir):
        os.makedirs(dir)

    state = {
        "net": net.state_dict(),
    }
    torch.save(state, path)


def test(net, dataloader, criterion, label, include):
    net.eval()
    with torch.no_grad():
        net_loss = 0
        correct = 0
        total = 0
        num_data = 0
        for _, (inputs, targets) in enumerate(dataloader):
            if include:
                idx = targets == label
            else:
                idx = targets != label
            inputs = inputs[idx]
            targets = targets[idx]
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            net_loss += loss * len(inputs)
            num_data +=  len(inputs)

            total += targets.size(0)
            _, predicted = outputs.max(1)
            correct += predicted.eq(targets).sum().item()

        accuracy = correct / total * 100
        net_loss /= num_data
        return net_loss, accuracy

def influence_test(net, dataloader, criterion, target_label):
    def sample_test(net, criterion, inputs, targets):
        net.eval()
        with torch.no_grad():
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            _, predicted = outputs.max(1)
            correct = predicted.eq(targets).sum().item()

            return loss, correct

    self_loss = 0
    self_correct = 0
    num_self_inputs = 0
    
    exclusive_loss = 0
    exclusive_correct = 0
    num_exclusive_inputs = 0
    
    for _, (inputs, targets) in enumerate(dataloader):
        target_idx = (targets == target_label)
        batch_self_loss, batch_self_correct = sample_test(net, criterion, inputs[target_idx], targets[target_idx])
        batch_exclusive_loss, batch_exclusive_correct = sample_test(net, criterion, inputs[~target_idx], targets[~target_idx])
        
        len_self_batch = len(inputs[target_idx])
        self_loss += batch_self_loss * len_self_batch
        self_correct += batch_self_correct
        num_self_inputs += len_self_batch
        
        len_exclusive_batch = len(inputs[~target_idx])
        exclusive_loss += batch_exclusive_loss * len_exclusive_batch
        exclusive_correct += batch_exclusive_correct
        num_exclusive_inputs += len_exclusive_batch
        
    self_loss /= num_self_inputs
    self_acc = self_correct / num_self_inputs * 100
    exclusive_loss /= num_exclusive_inputs
    exclusive_acc = exclusive_correct / num_exclusive_inputs * 100
    
    return self_loss, self_acc, exclusive_loss, exclusive_acc
        
def projected_influence(net, total_loss, target_loss, index_list, tol, step, max_iter, verbose):
    num_param = sum(p.numel() for p in net.parameters() if p.requires_grad)
    full_param_index_list = np.arange(num_param)
    influence = hessians.generalized_influence(
        net, total_loss, target_loss, full_param_index_list, tol=tol, step=step, max_iter=max_iter, verbose=verbose
    )
    return influence[index_list]

def f1_score(self_acc, test_acc):
    self_acc /= 100
    test_acc /= 100
    if self_acc == 1 and test_acc == 0:
        return 0
    return 2 * (1 - self_acc) * test_acc / (1 - self_acc + test_acc)

# %%
net = VGG11().to(device)
net_name = "VGG11"

if device == "cuda":
    cudnn.benchmark = True

net_path = f"checkpoints/tab2/{net_name}/cross_entropy/ckpt_0.0.pth"
net = load_net(net, net_path)

net.eval()
num_param = sum(p.numel() for p in net.parameters() if p.requires_grad)
print(
    f"==> Building {net_name} finished. "
    + f"\n    Number of parameters: {num_param}"
)

criterion = nn.CrossEntropyLoss()

# Data
print("==> Preparing data..")
batch_size = 512
num_workers = 16
num_sample_batch = 1
num_target_sample = 512

data_loader = cifar10.CIFAR10DataLoader(batch_size, num_workers, validation=False)
train_loader, test_loader = data_loader.get_data_loaders()

loss, acc = test(net, test_loader, criterion, 11, False)
print(
    f"Original loss and acc : {loss:.4f}, {acc:.2f}%"
)
# Out:
# ==> Building VGG11 finished.
#     Number of parameters: 9231114
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# Original loss and acc : 0.3518, 91.50%

# %%
verbose = True
verbose = True
num_exp = 10

removal_inputs = list()
removal_targets = list()
for batch_idx, (inputs, targets) in enumerate(test_loader):
    idx = targets == target_removal_label
    removal_inputs.append(inputs[idx])
    removal_targets.append(targets[idx])
removal_inputs = torch.cat(removal_inputs)
removal_targets = torch.cat(removal_targets)

ratio_list = [.1, .3, .5]
result_list_GIF = []
result_list_FIF = []
result_list_PIF = []

tol = 1e-9

for exp_iter in range(num_exp):
    sample_idx = np.random.choice(len(removal_inputs), num_target_sample, replace=False)
    for param_ratio in ratio_list:
        for i in range(3):
            if i == 0:
                if_name = "GIF"
            elif i == 1:
                if_name = "FIF"
            else:
                if_name = "PIF"

            print(f"{if_name} - ratio: {param_ratio*100}%, tol: {tol}")
            # Initialize network
            net = load_net(net, net_path)

            # Compute total loss
            total_loss = 0
            for batch_idx, (inputs, targets) in enumerate(test_loader):
                if batch_idx >= num_sample_batch:
                    break
                idx = targets != target_removal_label
                inputs, targets = inputs[idx], targets[idx]
                inputs, targets = inputs.to(device), targets.to(device)
                outputs = net(inputs)
                total_loss += criterion(outputs, targets)

            # Sampling the target removal data
            sample_removal_inputs = removal_inputs[sample_idx]
            sample_removal_targets = removal_targets[sample_idx]
            
            # Make hooks
            net_parser = selection.TopNGradients(net, param_ratio)
            net_parser.register_hooks()

            # Compute target loss
            target_loss = (
                criterion(net(sample_removal_inputs.to(device)), sample_removal_targets.to(device))
                * len(removal_inputs)
                / (len(train_loader.dataset) - len(removal_inputs))
            )
            target_loss.backward()
            net_parser.remove_hooks()

            target_loss = (
                criterion(net(sample_removal_inputs.to(device)), sample_removal_targets.to(device))
                * len(removal_inputs)
                / (len(train_loader.dataset) - len(removal_inputs))
            )
            
            # Delete hooks
            index_list = net_parser.get_parameters()
            net_parser.remove_hooks()
            
            if i == 0:
                influence = hessians.generalized_influence(
                    net, total_loss, target_loss, index_list, tol=tol, step=3, max_iter=30, verbose=False
                )
            elif i == 1:
                influence = freeze_influence.freeze_influence(
                    net, total_loss, target_loss, index_list, tol=tol, step=3, max_iter=30, verbose=False
                )
            else:
                influence = projected_influence(
                    net, total_loss, target_loss, index_list, tol=tol, step=3, max_iter=30, verbose=False
                )
                
            del total_loss, target_loss
            gc.collect()
            torch.cuda.empty_cache()
            
            influence *= 0.03 / torch.norm(influence)
                
            scale = 1 if i!=2 else 1 / param_ratio
            score = 0
            best_score = -1
            count = 1
            save_path = (
                f"checkpoints/tab2/{net_name}/{if_name}/{target_removal_label}_{param_ratio}_{exp_iter}.pth"
            )
            while True:
                if score < .85:
                    net_parser.update_network(influence * scale)
                else:
                    net_parser.update_network(influence * scale / 3)

#                 self_loss, self_acc = test(net, test_loader, criterion, target_removal_label, True)
#                 exclusive_loss, exclusive_acc = test(net, test_loader, criterion, target_removal_label, False)
                self_loss, self_acc, exclusive_loss, exclusive_acc = influence_test(net, test_loader, 
                                                                                    criterion, target_removal_label)
                score = f1_score(self_acc, exclusive_acc)
                
                if best_score < score:
                    best_result = [exclusive_acc, exclusive_loss, self_acc, self_loss, score]
                    best_score = score
                    save_net(net, save_path)
                    
                if verbose:
                    print(
                    f"{count} - test acc: {exclusive_acc:2.2f}, test loss: {exclusive_loss:.4f} |" +
                    f" self-acc: {self_acc:2.2f}%, self loss: {self_loss:.4f} | score: {score:.7f}",
                    end='\r'
                    )
                
                if exclusive_acc < 80 or self_acc < 0.01 or count >= 200:
                    if i == 0:
                        result_list_GIF += best_result
                    elif i == 1:
                        result_list_FIF += best_result
                    else:
                        result_list_PIF += best_result
                    
                    print(f"test acc: {best_result[0]:2.2f}, test loss: {best_result[1]:.4f} | " +
                          f"self-acc: {best_result[2]:2.2f}%, self loss: {best_result[3]:.4f} | " +
                          f"Score: {best_result[4]:.7f}" + " " * 20) 
                    break
                elif count >= 20 and best_score < 0.2:
                    scale *= 5
                elif count >= 50 and best_score < 0.5:
                    print(f"test acc: {best_result[0]:2.2f}, test loss: {best_result[1]:.4f} | " +
                          f"self-acc: {best_result[2]:2.2f}%, self loss: {best_result[3]:.4f} | " +
                          f"Score: {best_result[4]:.7f}" + " " * 20) 
                    break

                count += 1
                
        print("")
# Out:
# GIF - ratio: 10.0%, tol: 1e-09
# test acc: 88.47, test loss: 0.4806 | self-acc: 0.40%, self loss: 8.5266 | Score: 0.9370379
# FIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.58, test loss: 0.5201 | self-acc: 0.90%, self loss: 8.4626 | Score: 0.9298330
# PIF - ratio: 10.0%, tol: 1e-09
# test acc: 88.59, test loss: 0.4745 | self-acc: 2.50%, self loss: 7.6110 | Score: 0.9283108
#
# GIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.56, test loss: 0.5231 | self-acc: 1.00%, self loss: 8.8073 | Score: 0.9292674
# FIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.33, test loss: 0.5320 | self-acc: 1.60%, self loss: 8.5773 | Score: 0.9253697
# PIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.52, test loss: 0.5182 | self-acc: 1.90%, self loss: 8.3776 | Score: 0.9250972
#
# GIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.78, test loss: 0.5652 | self-acc: 1.20%, self loss: 8.8354 | Score: 0.9239947
# FIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.22, test loss: 0.5962 | self-acc: 1.20%, self loss: 8.9581 | Score: 0.9208359
# PIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.94, test loss: 0.5518 | self-acc: 1.60%, self loss: 8.4828 | Score: 0.9231821
#
# GIF - ratio: 10.0%, tol: 1e-09
# test acc: 88.09, test loss: 0.4876 | self-acc: 1.50%, self loss: 7.6666 | Score: 0.9300399
# FIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.47, test loss: 0.5333 | self-acc: 1.10%, self loss: 8.0228 | Score: 0.9283262
# PIF - ratio: 10.0%, tol: 1e-09
# test acc: 88.16, test loss: 0.4823 | self-acc: 3.00%, self loss: 7.1899 | Score: 0.9236654
#
# GIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.09, test loss: 0.5337 | self-acc: 1.40%, self loss: 8.2478 | Score: 0.9248765
# FIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.98, test loss: 0.5423 | self-acc: 1.70%, self loss: 8.2397 | Score: 0.9229294
# PIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.33, test loss: 0.5294 | self-acc: 2.30%, self loss: 7.8064 | Score: 0.9222627
#
# GIF - ratio: 50.0%, tol: 1e-09
# test acc: 85.37, test loss: 0.6186 | self-acc: 1.10%, self loss: 8.4869 | Score: 0.9163636
# FIF - ratio: 50.0%, tol: 1e-09
# test acc: 85.71, test loss: 0.6078 | self-acc: 1.80%, self loss: 8.3102 | Score: 0.9153151
# PIF - ratio: 50.0%, tol: 1e-09
# test acc: 85.99, test loss: 0.5871 | self-acc: 1.90%, self loss: 8.1321 | Score: 0.9164605
#
# GIF - ratio: 10.0%, tol: 1e-09
# test acc: 88.37, test loss: 0.4616 | self-acc: 0.60%, self loss: 8.4326 | Score: 0.9355917
# FIF - ratio: 10.0%, tol: 1e-09
# test acc: 88.24, test loss: 0.4898 | self-acc: 1.00%, self loss: 8.4820 | Score: 0.9331332
# PIF - ratio: 10.0%, tol: 1e-09
# test acc: 88.09, test loss: 0.4891 | self-acc: 3.80%, self loss: 7.6265 | Score: 0.9196595
#
# GIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.87, test loss: 0.4934 | self-acc: 1.00%, self loss: 8.5960 | Score: 0.9310168
# FIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.64, test loss: 0.5100 | self-acc: 1.10%, self loss: 8.7478 | Score: 0.9293266
# PIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.12, test loss: 0.5726 | self-acc: 0.60%, self loss: 9.0552 | Score: 0.9228597
#
# GIF - ratio: 50.0%, tol: 1e-09
# test acc: 87.00, test loss: 0.5360 | self-acc: 1.00%, self loss: 8.7362 | Score: 0.9261290
# FIF - ratio: 50.0%, tol: 1e-09
# test acc: 87.13, test loss: 0.5319 | self-acc: 0.50%, self loss: 9.0280 | Score: 0.9290695
# PIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.32, test loss: 0.5703 | self-acc: 0.80%, self loss: 8.7937 | Score: 0.9231416
#
# GIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.28, test loss: 0.5458 | self-acc: 0.30%, self loss: 9.1948 | Score: 0.9307624
# FIF - ratio: 10.0%, tol: 1e-09
# test acc: 86.96, test loss: 0.5686 | self-acc: 1.10%, self loss: 9.0062 | Score: 0.9254396
# PIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.78, test loss: 0.5140 | self-acc: 3.50%, self loss: 8.1302 | Score: 0.9193247
#
# GIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.17, test loss: 0.5945 | self-acc: 0.70%, self loss: 9.1636 | Score: 0.9226833
# FIF - ratio: 30.0%, tol: 1e-09
# test acc: 85.91, test loss: 0.6144 | self-acc: 1.00%, self loss: 9.1754 | Score: 0.9199231
# PIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.31, test loss: 0.5931 | self-acc: 2.00%, self loss: 8.6206 | Score: 0.9178490
#
# GIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.44, test loss: 0.5943 | self-acc: 2.20%, self loss: 8.6984 | Score: 0.9177228
# FIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.14, test loss: 0.6172 | self-acc: 2.10%, self loss: 8.7911 | Score: 0.9164679
# PIF - ratio: 50.0%, tol: 1e-09
# test acc: 85.80, test loss: 0.6111 | self-acc: 1.80%, self loss: 8.6438 | Score: 0.9158217
#
# GIF - ratio: 10.0%, tol: 1e-09
# test acc: 88.26, test loss: 0.4748 | self-acc: 0.40%, self loss: 8.6774 | Score: 0.9358524
# FIF - ratio: 10.0%, tol: 1e-09
# test acc: 86.83, test loss: 0.5595 | self-acc: 0.40%, self loss: 9.1248 | Score: 0.9277955
# PIF - ratio: 10.0%, tol: 1e-09
# test acc: 85.79, test loss: 0.6045 | self-acc: 0.30%, self loss: 9.5998 | Score: 0.9222280
#
# GIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.41, test loss: 0.5135 | self-acc: 0.70%, self loss: 8.8289 | Score: 0.9297704
# FIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.52, test loss: 0.5124 | self-acc: 1.00%, self loss: 8.8987 | Score: 0.9290796
# PIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.68, test loss: 0.5505 | self-acc: 0.70%, self loss: 8.9321 | Score: 0.9256056
#
# GIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.97, test loss: 0.5520 | self-acc: 0.80%, self loss: 8.9140 | Score: 0.9268140
# FIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.77, test loss: 0.5716 | self-acc: 0.50%, self loss: 9.2867 | Score: 0.9269810
# PIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.67, test loss: 0.5725 | self-acc: 1.30%, self loss: 8.7502 | Score: 0.9229275
#
# GIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.77, test loss: 0.5033 | self-acc: 0.90%, self loss: 8.3538 | Score: 0.9308965
# FIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.17, test loss: 0.5412 | self-acc: 1.80%, self loss: 8.0955 | Score: 0.9235497
# PIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.71, test loss: 0.5108 | self-acc: 3.60%, self loss: 7.5946 | Score: 0.9185053
#
# GIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.43, test loss: 0.5601 | self-acc: 1.00%, self loss: 8.6326 | Score: 0.9229085
# FIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.40, test loss: 0.5586 | self-acc: 1.80%, self loss: 8.4247 | Score: 0.9192286
# PIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.53, test loss: 0.5561 | self-acc: 1.70%, self loss: 8.2876 | Score: 0.9204213
#
# GIF - ratio: 50.0%, tol: 1e-09
# test acc: 85.80, test loss: 0.5981 | self-acc: 1.30%, self loss: 8.6264 | Score: 0.9179902
# FIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.02, test loss: 0.5896 | self-acc: 1.10%, self loss: 8.7207 | Score: 0.9201271
# PIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.13, test loss: 0.5886 | self-acc: 1.90%, self loss: 8.3130 | Score: 0.9172803
#
# GIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.20, test loss: 0.5586 | self-acc: 0.50%, self loss: 8.8144 | Score: 0.9294483
# FIF - ratio: 10.0%, tol: 1e-09
# test acc: 85.59, test loss: 0.6532 | self-acc: 1.50%, self loss: 8.7003 | Score: 0.9159168
# PIF - ratio: 10.0%, tol: 1e-09
# test acc: 86.96, test loss: 0.5635 | self-acc: 3.90%, self loss: 7.9712 | Score: 0.9129937
#
# GIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.50, test loss: 0.5847 | self-acc: 1.10%, self loss: 9.0568 | Score: 0.9228533
# FIF - ratio: 30.0%, tol: 1e-09
# test acc: 85.58, test loss: 0.6436 | self-acc: 0.80%, self loss: 9.3379 | Score: 0.9188676
# PIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.16, test loss: 0.5967 | self-acc: 2.00%, self loss: 8.6502 | Score: 0.9169687
#
# GIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.02, test loss: 0.6186 | self-acc: 1.80%, self loss: 8.8031 | Score: 0.9170861
# FIF - ratio: 50.0%, tol: 1e-09
# test acc: 85.24, test loss: 0.6610 | self-acc: 1.10%, self loss: 9.1831 | Score: 0.9156590
# PIF - ratio: 50.0%, tol: 1e-09
# test acc: 84.98, test loss: 0.6660 | self-acc: 1.20%, self loss: 9.1058 | Score: 0.9136909
#
# GIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.99, test loss: 0.5045 | self-acc: 1.10%, self loss: 8.1942 | Score: 0.9312593
# FIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.52, test loss: 0.5424 | self-acc: 1.80%, self loss: 8.0087 | Score: 0.9255416
# PIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.86, test loss: 0.5038 | self-acc: 3.60%, self loss: 7.5643 | Score: 0.9192966
#
# GIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.04, test loss: 0.5515 | self-acc: 1.30%, self loss: 8.4769 | Score: 0.9250653
# FIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.08, test loss: 0.5535 | self-acc: 1.80%, self loss: 8.5017 | Score: 0.9230506
# PIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.36, test loss: 0.5798 | self-acc: 1.30%, self loss: 8.2898 | Score: 0.9211605
#
# GIF - ratio: 50.0%, tol: 1e-09
# test acc: 85.60, test loss: 0.6207 | self-acc: 1.00%, self loss: 8.5925 | Score: 0.9181365
# FIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.43, test loss: 0.5928 | self-acc: 2.60%, self loss: 8.2231 | Score: 0.9158956
# PIF - ratio: 50.0%, tol: 1e-09
# test acc: 85.71, test loss: 0.6162 | self-acc: 1.60%, self loss: 8.3132 | Score: 0.9161830
#
# GIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.34, test loss: 0.5254 | self-acc: 0.90%, self loss: 8.5370 | Score: 0.9285162
# FIF - ratio: 10.0%, tol: 1e-09
# test acc: 86.87, test loss: 0.5660 | self-acc: 1.70%, self loss: 8.5523 | Score: 0.9223035
# PIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.58, test loss: 0.5262 | self-acc: 4.00%, self loss: 7.7276 | Score: 0.9159569
#
# GIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.88, test loss: 0.5587 | self-acc: 1.40%, self loss: 8.8134 | Score: 0.9236847
# FIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.30, test loss: 0.5458 | self-acc: 2.30%, self loss: 8.5539 | Score: 0.9220768
# PIF - ratio: 30.0%, tol: 1e-09
# test acc: 85.88, test loss: 0.5994 | self-acc: 1.90%, self loss: 8.5921 | Score: 0.9158291
#
# GIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.28, test loss: 0.6011 | self-acc: 2.00%, self loss: 8.6256 | Score: 0.9176605
# FIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.24, test loss: 0.6011 | self-acc: 2.50%, self loss: 8.5078 | Score: 0.9152748
# PIF - ratio: 50.0%, tol: 1e-09
# test acc: 85.34, test loss: 0.6376 | self-acc: 2.10%, self loss: 8.5992 | Score: 0.9119208
#
# GIF - ratio: 10.0%, tol: 1e-09
# test acc: 86.98, test loss: 0.5586 | self-acc: 0.60%, self loss: 9.5178 | Score: 0.9277491
# FIF - ratio: 10.0%, tol: 1e-09
# test acc: 86.12, test loss: 0.6166 | self-acc: 1.70%, self loss: 9.3935 | Score: 0.9180905
# PIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.41, test loss: 0.5300 | self-acc: 4.40%, self loss: 8.0972 | Score: 0.9132235
#
# GIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.21, test loss: 0.5500 | self-acc: 1.00%, self loss: 9.3497 | Score: 0.9273238
# FIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.48, test loss: 0.5856 | self-acc: 0.90%, self loss: 9.6059 | Score: 0.9235963
# PIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.26, test loss: 0.5916 | self-acc: 0.80%, self loss: 9.3675 | Score: 0.9227603
#
# GIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.86, test loss: 0.5744 | self-acc: 1.50%, self loss: 9.0822 | Score: 0.9231201
# FIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.24, test loss: 0.6054 | self-acc: 0.80%, self loss: 9.5117 | Score: 0.9226967
# PIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.06, test loss: 0.6077 | self-acc: 1.30%, self loss: 9.0815 | Score: 0.9194509

# %%
for param_ratio in ratio_list:
    print("")
    for i in range(3):
        if i == 0:
            if_name = "GIF"
        elif i == 1:
            if_name = "FIF"
        else:
            if_name = "PIF"
        print(f"{if_name} - ratio: {param_ratio*100}%, tol: {tol}")
        
        self_loss_list = np.empty(0)
        self_acc_list = np.empty(0)
        exclusive_loss_list = np.empty(0)
        exclusive_acc_list = np.empty(0)
        f1_score_list = np.empty(0)
        
        for exp_iter in range(num_exp):

            load_path = (
                f"checkpoints/tab2/{net_name}/{if_name}/{target_removal_label}_{param_ratio}_{exp_iter}.pth"
            )
            net = VGG11().to(device)
            net = load_net(net, load_path)
            self_loss, self_acc, exclusive_loss, exclusive_acc = influence_test(net, test_loader, 
                                                                    criterion, target_removal_label)
            score = f1_score(self_acc, exclusive_acc)
            
            self_loss_list = np.append(self_loss_list, self_loss.detach().cpu().numpy())
            self_acc_list = np.append(self_acc_list, self_acc)
            exclusive_loss_list = np.append(exclusive_loss_list, exclusive_loss.detach().cpu().numpy())
            exclusive_acc_list = np.append(exclusive_acc_list, exclusive_acc)
            f1_score_list = np.append(f1_score_list, score)
            print(
            f"  test acc: {exclusive_acc:2.2f}, test loss: {exclusive_loss:.4f} | " +
            f"self-acc: {self_acc:2.2f}%, self loss: {self_loss:.4f} | score: {score:.4f}",
            end='\r'
            )
            
        mean_self_loss = np.mean(self_loss_list)
        mean_self_acc = np.mean(self_acc_list)
        mean_exclusive_loss = np.mean(exclusive_loss_list)
        mean_exclusive_acc = np.mean(exclusive_acc_list)
        mean_f1_score = np.mean(f1_score_list)
                
        var_self_loss = np.var(self_loss_list)
        var_self_acc = np.var(self_acc_list)
        var_exclusive_loss = np.var(exclusive_loss_list)
        var_exclusive_acc = np.var(exclusive_acc_list)
        var_f1_score = np.var(f1_score_list)

        print(
        f"test acc: {mean_exclusive_acc:2.2f}+-{var_exclusive_acc:2.2f}% " +
        f"test loss: {mean_exclusive_loss:.4f}+-{var_exclusive_loss:.4f} ", end=""
        )
        print(
        f"self-acc: {mean_self_acc:2.2f}+-{var_self_acc:2.2f}% " +
        f"self loss: {mean_self_loss:.4f}+-{var_self_loss:.4f} " +
        f"score: {mean_f1_score:.4f}",
        )
# Out:
# GIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.88+-0.50% test loss: 0.5048+-0.0017 self-acc: 0.79+-0.13% self loss: 8.6195+-0.2415 score: 0.9320
# FIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.19+-0.89% test loss: 0.5522+-0.0030 self-acc: 1.31+-0.19% self loss: 8.6593+-0.2367 score: 0.9258
# PIF - ratio: 10.0%, tol: 1e-09
# test acc: 87.61+-0.57% test loss: 0.5186+-0.0015 self-acc: 3.22+-1.30% self loss: 7.9641+-0.3817 score: 0.9196
# GIF - ratio: 30.0%, tol: 1e-09
# test acc: 87.20+-0.75% test loss: 0.5371+-0.0021 self-acc: 1.04+-0.06% self loss: 8.8214+-0.1037 score: 0.9271
# FIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.99+-0.85% test loss: 0.5510+-0.0029 self-acc: 1.31+-0.26% self loss: 8.9005+-0.2113 score: 0.9247
# PIF - ratio: 30.0%, tol: 1e-09
# test acc: 86.57+-0.39% test loss: 0.5657+-0.0011 self-acc: 1.41+-0.37% self loss: 8.6628+-0.1876 score: 0.9219
# GIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.31+-0.32% test loss: 0.5879+-0.0008 self-acc: 1.39+-0.20% self loss: 8.7401+-0.0274 score: 0.9205
# FIF - ratio: 50.0%, tol: 1e-09
# test acc: 86.22+-0.24% test loss: 0.5975+-0.0010 self-acc: 1.42+-0.55% self loss: 8.8520+-0.1604 score: 0.9198
# PIF - ratio: 50.0%, tol: 1e-09
# test acc: 85.99+-0.31% test loss: 0.6009+-0.0010 self-acc: 1.55+-0.14% self loss: 8.6215+-0.0942 score: 0.9180

# %%
retrained_net = VGG11().to(device)
net_name = "VGG11"
net_path = f"checkpoints/tab2/{net_name}_retrained/cross_entropy/ckpt_0.0_{target_removal_label}.pth"
print(net_path)
retrained_net = load_net(retrained_net, net_path)

self_loss, self_acc = test(retrained_net, test_loader, criterion, target_removal_label, True)
exclusive_loss, exclusive_acc = test(retrained_net, test_loader, criterion, target_removal_label, False)
score = f1_score(self_acc, exclusive_acc)

print(
f"test acc: {exclusive_acc:2.2f}, test loss: {exclusive_loss:.4f} |" +
f" self-acc: {self_acc:2.2f}%, self loss: {self_loss:.4f} | score: {score:.7f}",
)
# Out:
# checkpoints/tab2/VGG11_retrained/cross_entropy/ckpt_0.0_0.pth
# test acc: 91.76, test loss: 0.3447 | self-acc: 0.00%, self loss: 8.1924 | score: 0.9570054

# %% [markdown]
# ##
